# %%
import requests
from bs4 import BeautifulSoup
import time
import re
import random
import pandas as pd

# %%
Movies = pd.read_csv('Movielist_Marvel.csv')
Movies
# Out:
#                                    name  \
# 0    Captain America: The First Avenger
# 1                              Iron Man
# 2                   The Incredible Hulk
# 3                            Iron Man 2
# 4                                  Thor
# 5                          The Avengers
# 6                        Iron Man Three
# 7                  Thor: The Dark World
# 8   Captain America: The Winter Soldier
# 9               Guardians of the Galaxy
# 10       Guardians of the Galaxy Vol. 2
# 11              Avengers: Age of Ultron
# 12                              Ant-Man
# 13           Captain America: Civil War
# 14               Spider-Man: Homecoming
# 15                       Doctor Strange
# 16                       Thor: Ragnarok
# 17                        Black Panther
# 18               Avengers: Infinity War
# 19                 Ant-Man and the Wasp
# 20                       Captain Marvel
#
#                                   name_link
# 0         captain_america_the_first_avenger
# 1                                  iron_man
# 2                       the_incredible_hulk
# 3                                iron_man_2
# 4                                      thor
# 5                      marvels_the_avengers
# 6                                iron_man_3
# 7                       thor_the_dark_world
# 8   captain_america_the_winter_soldier_2014
# 9                   guardians_of_the_galaxy
# 10            guardians_of_the_galaxy_vol_2
# 11                   avengers_age_of_ultron
# 12                                   antman
# 13                captain_america_civil_war
# 14                    spider_man_homecoming
# 15                      doctor_strange_2016
# 16                       thor_ragnarok_2017
# 17                       black_panther_2018
# 18                    avengers_infinity_war
# 19                     ant_man_and_the_wasp
# 20                           captain_marvel

# %%
user_agents = ['Mozilla/5.0 (Windows NT 6.1; rv:2.0.1) Gecko/20100101 Firefox/4.0.1',
               'Mozilla/5.0 (Windows; U; Windows NT 6.1; en-us) AppleWebKit/534.50 (KHTML, like Gecko) Version/5.1 Safari/534.50',
               'Opera/9.80 (Windows NT 6.1; U; en) Presto/2.8.131 Version/11.11']

# %%
def find_star_missing(soup):
    # find the indexes for star missing
    star_missing = []
    review_frame=soup.find_all('div',class_='col-xs-16')
    for i in range(len(review_frame)):
        if not review_frame[i].find('span', class_="glyphicon glyphicon-star") and not review_frame[i].find(text = re.compile('\xbd')):
            star_missing.append(i)
    return star_missing

def crawler(url):
    # fetch html by url
    headers = {'User-Agent':random.choice(user_agents)}
    r = requests.get(url, timeout=(3.05, 10), headers = headers)
    soup = BeautifulSoup(r.text, 'html.parser')

    # parse html
    try:
        data = []
        user_review=soup.find_all('div',class_='user_review')
        stars=soup.find_all('span',class_='fl')
        date=soup.find_all('span',class_='fr small subtle')
        for i in range(len(user_review)):        
            stars_single = len(stars[i].find_all('span', class_="glyphicon glyphicon-star")) + float(len(stars[i].text)-1)/2            
            data.append((user_review[i].text, stars_single, date[i].text))
            
    except: # star missing
        data = []
        user_review=soup.find_all('div',class_='user_review')
        stars=soup.find_all('span',class_='fl')
        date=soup.find_all('span',class_='fr small subtle')
        
        # insert star missing
        star_missing = find_star_missing(soup)
        for insert_index in star_missing:    
            stars.insert(insert_index,0)
            
        for i in range(len(user_review)):
            if stars[i] == 0:
                stars_single = 0
            else:
                stars_single = len(stars[i].find_all('span', class_="glyphicon glyphicon-star")) + float(len(stars[i].text)-1)/2             
            data.append((user_review[i].text, stars_single, date[i].text))
            
    return data

# %%
for name_link in Movies['name_link']:
    index = Movies.index[Movies['name_link'] == name_link].tolist()[0]
    data = []
    # 1st page
    url = 'https://www.rottentomatoes.com/m/' + name_link + '/reviews/?type=user&sort='
    data = crawler(url)
    print(name_link, "page%d"%1, "Total reviews:%d"%len(data))
    # 2-51st page
    for i in range(2,52):
        attempts = 0
        success = False
        while attempts < 3 and not success:    
            try:
                time.sleep(random.uniform(1, 2))
                url = 'https://www.rottentomatoes.com/m/' + name_link + '/reviews/?page='+ str(i) + '&type=user&sort='
                data_page = crawler(url)
                data = data + data_page
                print(name_link, "page%d"%i, "Total reviews:%d"%len(data_page))
                success = True
            except:
                attempts += 1
                if attempts == 3:
                    print(i, 'error')
    # output
    df = pd.DataFrame(data, columns=['review', 'stars', 'date'])
    df.to_csv('Reviews_Marvel/'+Movies['name'][index]+'.csv', index=False, encoding='utf-8')
    print(name_link, "Finished task %d"%index, "Total reviews:%d"%len(df))
# Out:
# ('captain_america_the_first_avenger', 'page1', 'Total reviews:20')
# ('captain_america_the_first_avenger', 'page2', 'Total reviews:19')
# ('captain_america_the_first_avenger', 'page3', 'Total reviews:20')
# ('captain_america_the_first_avenger', 'page4', 'Total reviews:20')
# ('captain_america_the_first_avenger', 'page5', 'Total reviews:20')
# ('captain_america_the_first_avenger', 'page6', 'Total reviews:20')
# ('captain_america_the_first_avenger', 'page7', 'Total reviews:20')
# ('captain_america_the_first_avenger', 'page8', 'Total reviews:19')
# ('captain_america_the_first_avenger', 'page9', 'Total reviews:19')
# ('captain_america_the_first_avenger', 'page10', 'Total reviews:20')
# ('captain_america_the_first_avenger', 'page11', 'Total reviews:20')
# ('captain_america_the_first_avenger', 'page12', 'Total reviews:20')
# ('captain_america_the_first_avenger', 'page13', 'Total reviews:20')
# ('captain_america_the_first_avenger', 'page14', 'Total reviews:20')
# ('captain_america_the_first_avenger', 'page15', 'Total reviews:20')
# ('captain_america_the_first_avenger', 'page16', 'Total reviews:20')
# ('captain_america_the_first_avenger', 'page17', 'Total reviews:19')
# ('captain_america_the_first_avenger', 'page18', 'Total reviews:20')
# ('captain_america_the_first_avenger', 'page19', 'Total reviews:20')
# ('captain_america_the_first_avenger', 'page20', 'Total reviews:20')
# ('captain_america_the_first_avenger', 'page21', 'Total reviews:20')
# ('captain_america_the_first_avenger', 'page22', 'Total reviews:20')
# ('captain_america_the_first_avenger', 'page23', 'Total reviews:19')
# ('captain_america_the_first_avenger', 'page24', 'Total reviews:20')
# ('captain_america_the_first_avenger', 'page25', 'Total reviews:20')
# ('captain_america_the_first_avenger', 'page26', 'Total reviews:19')
# ('captain_america_the_first_avenger', 'page27', 'Total reviews:19')
# ('captain_america_the_first_avenger', 'page28', 'Total reviews:20')
# ('captain_america_the_first_avenger', 'page29', 'Total reviews:20')
# ('captain_america_the_first_avenger', 'page30', 'Total reviews:19')
# ('captain_america_the_first_avenger', 'page31', 'Total reviews:20')
# ('captain_america_the_first_avenger', 'page32', 'Total reviews:20')
# ('captain_america_the_first_avenger', 'page33', 'Total reviews:20')
# ('captain_america_the_first_avenger', 'page34', 'Total reviews:18')
# ('captain_america_the_first_avenger', 'page35', 'Total reviews:20')
# ('captain_america_the_first_avenger', 'page36', 'Total reviews:20')
# ('captain_america_the_first_avenger', 'page37', 'Total reviews:20')
# ('captain_america_the_first_avenger', 'page38', 'Total reviews:20')
# ('captain_america_the_first_avenger', 'page39', 'Total reviews:20')
# ('captain_america_the_first_avenger', 'page40', 'Total reviews:20')
# ('captain_america_the_first_avenger', 'page41', 'Total reviews:19')
# ('captain_america_the_first_avenger', 'page42', 'Total reviews:20')
# ('captain_america_the_first_avenger', 'page43', 'Total reviews:20')
# ('captain_america_the_first_avenger', 'page44', 'Total reviews:20')
# ('captain_america_the_first_avenger', 'page45', 'Total reviews:20')
# ('captain_america_the_first_avenger', 'page46', 'Total reviews:19')
# ('captain_america_the_first_avenger', 'page47', 'Total reviews:19')
# ('captain_america_the_first_avenger', 'page48', 'Total reviews:20')
# ('captain_america_the_first_avenger', 'page49', 'Total reviews:20')
# ('captain_america_the_first_avenger', 'page50', 'Total reviews:20')
# ('captain_america_the_first_avenger', 'page51', 'Total reviews:19')
# ('captain_america_the_first_avenger', 'Finished task 0', 'Total reviews:1006')
# ('iron_man', 'page1', 'Total reviews:20')
# ('iron_man', 'page2', 'Total reviews:19')
# ('iron_man', 'page3', 'Total reviews:20')
# ('iron_man', 'page4', 'Total reviews:20')
# ('iron_man', 'page5', 'Total reviews:20')
# ('iron_man', 'page6', 'Total reviews:20')
# ('iron_man', 'page7', 'Total reviews:20')
# ('iron_man', 'page8', 'Total reviews:20')
# ('iron_man', 'page9', 'Total reviews:20')
# ('iron_man', 'page10', 'Total reviews:20')
# ('iron_man', 'page11', 'Total reviews:19')
# ('iron_man', 'page12', 'Total reviews:19')
# ('iron_man', 'page13', 'Total reviews:20')
# ('iron_man', 'page14', 'Total reviews:20')
# ('iron_man', 'page15', 'Total reviews:20')
# ('iron_man', 'page16', 'Total reviews:20')
# ('iron_man', 'page17', 'Total reviews:20')
# ('iron_man', 'page18', 'Total reviews:20')
# ('iron_man', 'page19', 'Total reviews:20')
# ('iron_man', 'page20', 'Total reviews:20')
# ('iron_man', 'page21', 'Total reviews:20')
# ('iron_man', 'page22', 'Total reviews:20')
# ('iron_man', 'page23', 'Total reviews:20')
# ('iron_man', 'page24', 'Total reviews:18')
# ('iron_man', 'page25', 'Total reviews:20')
# ('iron_man', 'page26', 'Total reviews:20')
# ('iron_man', 'page27', 'Total reviews:20')
# ('iron_man', 'page28', 'Total reviews:20')
# ('iron_man', 'page29', 'Total reviews:20')
# ('iron_man', 'page30', 'Total reviews:20')
# ('iron_man', 'page31', 'Total reviews:20')
# ('iron_man', 'page32', 'Total reviews:19')
# ('iron_man', 'page33', 'Total reviews:19')
# ('iron_man', 'page34', 'Total reviews:20')
# ('iron_man', 'page35', 'Total reviews:20')
# ('iron_man', 'page36', 'Total reviews:20')
# ('iron_man', 'page37', 'Total reviews:20')
# ('iron_man', 'page38', 'Total reviews:19')
# ('iron_man', 'page39', 'Total reviews:20')
# ('iron_man', 'page40', 'Total reviews:20')
# ('iron_man', 'page41', 'Total reviews:20')
# ('iron_man', 'page42', 'Total reviews:17')
# ('iron_man', 'page43', 'Total reviews:20')
# ('iron_man', 'page44', 'Total reviews:20')
# ('iron_man', 'page45', 'Total reviews:20')
# ('iron_man', 'page46', 'Total reviews:20')
# ('iron_man', 'page47', 'Total reviews:19')
# ('iron_man', 'page48', 'Total reviews:20')
# ('iron_man', 'page49', 'Total reviews:20')
# ('iron_man', 'page50', 'Total reviews:19')
# ('iron_man', 'page51', 'Total reviews:20')
# ('iron_man', 'Finished task 1', 'Total reviews:1007')
# ('the_incredible_hulk', 'page1', 'Total reviews:19')
# ('the_incredible_hulk', 'page2', 'Total reviews:20')
# ('the_incredible_hulk', 'page3', 'Total reviews:20')
# ('the_incredible_hulk', 'page4', 'Total reviews:20')
# ('the_incredible_hulk', 'page5', 'Total reviews:20')
# ('the_incredible_hulk', 'page6', 'Total reviews:20')
# ('the_incredible_hulk', 'page7', 'Total reviews:19')
# ('the_incredible_hulk', 'page8', 'Total reviews:20')
# ('the_incredible_hulk', 'page9', 'Total reviews:20')
# ('the_incredible_hulk', 'page10', 'Total reviews:20')
# ('the_incredible_hulk', 'page11', 'Total reviews:19')
# ('the_incredible_hulk', 'page12', 'Total reviews:20')
# ('the_incredible_hulk', 'page13', 'Total reviews:20')
# ('the_incredible_hulk', 'page14', 'Total reviews:20')
# ('the_incredible_hulk', 'page15', 'Total reviews:19')
# ('the_incredible_hulk', 'page16', 'Total reviews:20')
# ('the_incredible_hulk', 'page17', 'Total reviews:20')
# ('the_incredible_hulk', 'page18', 'Total reviews:20')
# ('the_incredible_hulk', 'page19', 'Total reviews:20')
# ('the_incredible_hulk', 'page20', 'Total reviews:19')
# ('the_incredible_hulk', 'page21', 'Total reviews:20')
# ('the_incredible_hulk', 'page22', 'Total reviews:20')
# ('the_incredible_hulk', 'page23', 'Total reviews:20')
# ('the_incredible_hulk', 'page24', 'Total reviews:20')
# ('the_incredible_hulk', 'page25', 'Total reviews:20')
# ('the_incredible_hulk', 'page26', 'Total reviews:18')
# ('the_incredible_hulk', 'page27', 'Total reviews:19')
# ('the_incredible_hulk', 'page28', 'Total reviews:20')
# ('the_incredible_hulk', 'page29', 'Total reviews:20')
# ('the_incredible_hulk', 'page30', 'Total reviews:19')
# ('the_incredible_hulk', 'page31', 'Total reviews:20')
# ('the_incredible_hulk', 'page32', 'Total reviews:20')
# ('the_incredible_hulk', 'page33', 'Total reviews:20')
# ('the_incredible_hulk', 'page34', 'Total reviews:20')
# ('the_incredible_hulk', 'page35', 'Total reviews:20')
# ('the_incredible_hulk', 'page36', 'Total reviews:20')
# ('the_incredible_hulk', 'page37', 'Total reviews:20')
# ('the_incredible_hulk', 'page38', 'Total reviews:20')
# ('the_incredible_hulk', 'page39', 'Total reviews:20')
# ('the_incredible_hulk', 'page40', 'Total reviews:20')
# ('the_incredible_hulk', 'page41', 'Total reviews:20')
# ('the_incredible_hulk', 'page42', 'Total reviews:20')
# ('the_incredible_hulk', 'page43', 'Total reviews:20')
# ('the_incredible_hulk', 'page44', 'Total reviews:19')
# ('the_incredible_hulk', 'page45', 'Total reviews:20')
# ('the_incredible_hulk', 'page46', 'Total reviews:20')
# ('the_incredible_hulk', 'page47', 'Total reviews:20')
# ('the_incredible_hulk', 'page48', 'Total reviews:20')
# ('the_incredible_hulk', 'page49', 'Total reviews:20')
# ('the_incredible_hulk', 'page50', 'Total reviews:20')
# ('the_incredible_hulk', 'page51', 'Total reviews:20')
# ('the_incredible_hulk', 'Finished task 2', 'Total reviews:1010')
# ('iron_man_2', 'page1', 'Total reviews:19')
# ('iron_man_2', 'page2', 'Total reviews:20')
# ('iron_man_2', 'page3', 'Total reviews:20')
# ('iron_man_2', 'page4', 'Total reviews:20')
# ('iron_man_2', 'page5', 'Total reviews:20')
# ('iron_man_2', 'page6', 'Total reviews:20')
# ('iron_man_2', 'page7', 'Total reviews:18')
# ('iron_man_2', 'page8', 'Total reviews:20')
# ('iron_man_2', 'page9', 'Total reviews:20')
# ('iron_man_2', 'page10', 'Total reviews:20')
# ('iron_man_2', 'page11', 'Total reviews:19')
# ('iron_man_2', 'page12', 'Total reviews:20')
# ('iron_man_2', 'page13', 'Total reviews:20')
# ('iron_man_2', 'page14', 'Total reviews:20')
# ('iron_man_2', 'page15', 'Total reviews:20')
# ('iron_man_2', 'page16', 'Total reviews:19')
# ('iron_man_2', 'page17', 'Total reviews:20')
# ('iron_man_2', 'page18', 'Total reviews:20')
# ('iron_man_2', 'page19', 'Total reviews:20')
# ('iron_man_2', 'page20', 'Total reviews:20')
# ('iron_man_2', 'page21', 'Total reviews:20')
# ('iron_man_2', 'page22', 'Total reviews:19')
# ('iron_man_2', 'page23', 'Total reviews:20')
# ('iron_man_2', 'page24', 'Total reviews:20')
# ('iron_man_2', 'page25', 'Total reviews:20')
# ('iron_man_2', 'page26', 'Total reviews:20')
# ('iron_man_2', 'page27', 'Total reviews:20')
# ('iron_man_2', 'page28', 'Total reviews:20')
# ('iron_man_2', 'page29', 'Total reviews:20')
# ('iron_man_2', 'page30', 'Total reviews:18')
# ('iron_man_2', 'page31', 'Total reviews:20')
# ('iron_man_2', 'page32', 'Total reviews:20')
# ('iron_man_2', 'page33', 'Total reviews:19')
# ('iron_man_2', 'page34', 'Total reviews:20')
# ('iron_man_2', 'page35', 'Total reviews:19')
# ('iron_man_2', 'page36', 'Total reviews:20')
# ('iron_man_2', 'page37', 'Total reviews:20')
# ('iron_man_2', 'page38', 'Total reviews:20')
# ('iron_man_2', 'page39', 'Total reviews:20')
# ('iron_man_2', 'page40', 'Total reviews:20')
# ('iron_man_2', 'page41', 'Total reviews:19')
# ('iron_man_2', 'page42', 'Total reviews:20')
# ('iron_man_2', 'page43', 'Total reviews:20')
# ('iron_man_2', 'page44', 'Total reviews:20')
# ('iron_man_2', 'page45', 'Total reviews:19')
# ('iron_man_2', 'page46', 'Total reviews:20')
# ('iron_man_2', 'page47', 'Total reviews:19')
# ('iron_man_2', 'page48', 'Total reviews:20')
# ('iron_man_2', 'page49', 'Total reviews:20')
# ('iron_man_2', 'page50', 'Total reviews:20')
# ('iron_man_2', 'page51', 'Total reviews:20')
# ('iron_man_2', 'Finished task 3', 'Total reviews:1007')
# ('thor', 'page1', 'Total reviews:20')
# ('thor', 'page2', 'Total reviews:19')
# ('thor', 'page3', 'Total reviews:20')
# ('thor', 'page4', 'Total reviews:20')
# ('thor', 'page5', 'Total reviews:20')
# ('thor', 'page6', 'Total reviews:20')
# ('thor', 'page7', 'Total reviews:19')
# ('thor', 'page8', 'Total reviews:19')
# ('thor', 'page9', 'Total reviews:20')
# ('thor', 'page10', 'Total reviews:20')
# ('thor', 'page11', 'Total reviews:20')
# ('thor', 'page12', 'Total reviews:20')
# ('thor', 'page13', 'Total reviews:20')
# ('thor', 'page14', 'Total reviews:20')
# ('thor', 'page15', 'Total reviews:20')
# ('thor', 'page16', 'Total reviews:20')
# ('thor', 'page17', 'Total reviews:19')
# ('thor', 'page18', 'Total reviews:20')
# ('thor', 'page19', 'Total reviews:20')
# ('thor', 'page20', 'Total reviews:20')
# ('thor', 'page21', 'Total reviews:20')
# ('thor', 'page22', 'Total reviews:20')
# ('thor', 'page23', 'Total reviews:19')
# ('thor', 'page24', 'Total reviews:20')
# ('thor', 'page25', 'Total reviews:20')
# ('thor', 'page26', 'Total reviews:20')
# ('thor', 'page27', 'Total reviews:20')
# ('thor', 'page28', 'Total reviews:18')
# ('thor', 'page29', 'Total reviews:20')
# ('thor', 'page30', 'Total reviews:20')
# ('thor', 'page31', 'Total reviews:20')
# ('thor', 'page32', 'Total reviews:19')
# ('thor', 'page33', 'Total reviews:19')
# ('thor', 'page34', 'Total reviews:20')
# ('thor', 'page35', 'Total reviews:19')
# ('thor', 'page36', 'Total reviews:20')
# ('thor', 'page37', 'Total reviews:20')
# ('thor', 'page38', 'Total reviews:19')
# ('thor', 'page39', 'Total reviews:20')
# ('thor', 'page40', 'Total reviews:20')
# ('thor', 'page41', 'Total reviews:20')
# ('thor', 'page42', 'Total reviews:20')
# ('thor', 'page43', 'Total reviews:20')
# ('thor', 'page44', 'Total reviews:20')
# ('thor', 'page45', 'Total reviews:20')
# ('thor', 'page46', 'Total reviews:20')
# ('thor', 'page47', 'Total reviews:20')
# ('thor', 'page48', 'Total reviews:20')
# ('thor', 'page49', 'Total reviews:20')
# ('thor', 'page50', 'Total reviews:20')
# ('thor', 'page51', 'Total reviews:20')
# ('thor', 'Finished task 4', 'Total reviews:1009')
# ('marvels_the_avengers', 'page1', 'Total reviews:19')
# ('marvels_the_avengers', 'page2', 'Total reviews:19')
# ('marvels_the_avengers', 'page3', 'Total reviews:20')
# ('marvels_the_avengers', 'page4', 'Total reviews:20')
# ('marvels_the_avengers', 'page5', 'Total reviews:20')
# ('marvels_the_avengers', 'page6', 'Total reviews:20')
# ('marvels_the_avengers', 'page7', 'Total reviews:20')
# ('marvels_the_avengers', 'page8', 'Total reviews:20')
# ('marvels_the_avengers', 'page9', 'Total reviews:19')
# ('marvels_the_avengers', 'page10', 'Total reviews:20')
# ('marvels_the_avengers', 'page11', 'Total reviews:20')
# ('marvels_the_avengers', 'page12', 'Total reviews:20')
# ('marvels_the_avengers', 'page13', 'Total reviews:20')
# ('marvels_the_avengers', 'page14', 'Total reviews:20')
# ('marvels_the_avengers', 'page15', 'Total reviews:20')
# ('marvels_the_avengers', 'page16', 'Total reviews:19')
# ('marvels_the_avengers', 'page17', 'Total reviews:20')
# ('marvels_the_avengers', 'page18', 'Total reviews:20')
# ('marvels_the_avengers', 'page19', 'Total reviews:20')
# ('marvels_the_avengers', 'page20', 'Total reviews:20')
# ('marvels_the_avengers', 'page21', 'Total reviews:20')
# ('marvels_the_avengers', 'page22', 'Total reviews:20')
# ('marvels_the_avengers', 'page23', 'Total reviews:19')
# ('marvels_the_avengers', 'page24', 'Total reviews:20')
# ('marvels_the_avengers', 'page25', 'Total reviews:20')
# ('marvels_the_avengers', 'page26', 'Total reviews:20')
# ('marvels_the_avengers', 'page27', 'Total reviews:20')
# ('marvels_the_avengers', 'page28', 'Total reviews:20')
# ('marvels_the_avengers', 'page29', 'Total reviews:20')
# ('marvels_the_avengers', 'page30', 'Total reviews:19')
# ('marvels_the_avengers', 'page31', 'Total reviews:20')
# ('marvels_the_avengers', 'page32', 'Total reviews:20')
# ('marvels_the_avengers', 'page33', 'Total reviews:19')
# ('marvels_the_avengers', 'page34', 'Total reviews:20')
# ('marvels_the_avengers', 'page35', 'Total reviews:19')
# ('marvels_the_avengers', 'page36', 'Total reviews:18')
# ('marvels_the_avengers', 'page37', 'Total reviews:20')
# ('marvels_the_avengers', 'page38', 'Total reviews:20')
# ('marvels_the_avengers', 'page39', 'Total reviews:20')
# ('marvels_the_avengers', 'page40', 'Total reviews:20')
# ('marvels_the_avengers', 'page41', 'Total reviews:20')
# ('marvels_the_avengers', 'page42', 'Total reviews:20')
# ('marvels_the_avengers', 'page43', 'Total reviews:20')
# ('marvels_the_avengers', 'page44', 'Total reviews:20')
# ('marvels_the_avengers', 'page45', 'Total reviews:20')
# ('marvels_the_avengers', 'page46', 'Total reviews:20')
# ('marvels_the_avengers', 'page47', 'Total reviews:20')
# ('marvels_the_avengers', 'page48', 'Total reviews:19')
# ('marvels_the_avengers', 'page49', 'Total reviews:19')
# ('marvels_the_avengers', 'page50', 'Total reviews:20')
# ('marvels_the_avengers', 'page51', 'Total reviews:20')
# ('marvels_the_avengers', 'Finished task 5', 'Total reviews:1008')
# ('iron_man_3', 'page1', 'Total reviews:20')
# ('iron_man_3', 'page2', 'Total reviews:19')
# ('iron_man_3', 'page3', 'Total reviews:20')
# ('iron_man_3', 'page4', 'Total reviews:20')
# ('iron_man_3', 'page5', 'Total reviews:20')
# ('iron_man_3', 'page6', 'Total reviews:20')
# ('iron_man_3', 'page7', 'Total reviews:18')
# ('iron_man_3', 'page8', 'Total reviews:20')
# ('iron_man_3', 'page9', 'Total reviews:20')
# ('iron_man_3', 'page10', 'Total reviews:20')
# ('iron_man_3', 'page11', 'Total reviews:20')
# ('iron_man_3', 'page12', 'Total reviews:20')
# ('iron_man_3', 'page13', 'Total reviews:19')
# ('iron_man_3', 'page14', 'Total reviews:20')
# ('iron_man_3', 'page15', 'Total reviews:19')
# ('iron_man_3', 'page16', 'Total reviews:20')
# ('iron_man_3', 'page17', 'Total reviews:19')
# ('iron_man_3', 'page18', 'Total reviews:20')
# ('iron_man_3', 'page19', 'Total reviews:20')
# ('iron_man_3', 'page20', 'Total reviews:20')
# ('iron_man_3', 'page21', 'Total reviews:20')
# ('iron_man_3', 'page22', 'Total reviews:20')
# ('iron_man_3', 'page23', 'Total reviews:20')
# ('iron_man_3', 'page24', 'Total reviews:20')
# ('iron_man_3', 'page25', 'Total reviews:19')
# ('iron_man_3', 'page26', 'Total reviews:19')
# ('iron_man_3', 'page27', 'Total reviews:20')
# ('iron_man_3', 'page28', 'Total reviews:19')
# ('iron_man_3', 'page29', 'Total reviews:19')
# ('iron_man_3', 'page30', 'Total reviews:20')
# ('iron_man_3', 'page31', 'Total reviews:20')
# ('iron_man_3', 'page32', 'Total reviews:20')
# ('iron_man_3', 'page33', 'Total reviews:20')
# ('iron_man_3', 'page34', 'Total reviews:20')
# ('iron_man_3', 'page35', 'Total reviews:20')
# ('iron_man_3', 'page36', 'Total reviews:20')
# ('iron_man_3', 'page37', 'Total reviews:20')
# ('iron_man_3', 'page38', 'Total reviews:20')
# ('iron_man_3', 'page39', 'Total reviews:18')
# ('iron_man_3', 'page40', 'Total reviews:20')
# ('iron_man_3', 'page41', 'Total reviews:19')
# ('iron_man_3', 'page42', 'Total reviews:19')
# ('iron_man_3', 'page43', 'Total reviews:20')
# ('iron_man_3', 'page44', 'Total reviews:20')
# ('iron_man_3', 'page45', 'Total reviews:20')
# ('iron_man_3', 'page46', 'Total reviews:20')
# ('iron_man_3', 'page47', 'Total reviews:20')
# ('iron_man_3', 'page48', 'Total reviews:20')
# ('iron_man_3', 'page49', 'Total reviews:20')
# ('iron_man_3', 'page50', 'Total reviews:19')
# ('iron_man_3', 'page51', 'Total reviews:20')
# ('iron_man_3', 'Finished task 6', 'Total reviews:1005')
# ('thor_the_dark_world', 'page1', 'Total reviews:19')
# ('thor_the_dark_world', 'page2', 'Total reviews:20')
# ('thor_the_dark_world', 'page3', 'Total reviews:20')
# ('thor_the_dark_world', 'page4', 'Total reviews:20')
# ('thor_the_dark_world', 'page5', 'Total reviews:20')
# ('thor_the_dark_world', 'page6', 'Total reviews:19')
# ('thor_the_dark_world', 'page7', 'Total reviews:20')
# ('thor_the_dark_world', 'page8', 'Total reviews:20')
# ('thor_the_dark_world', 'page9', 'Total reviews:20')
# ('thor_the_dark_world', 'page10', 'Total reviews:20')
# ('thor_the_dark_world', 'page11', 'Total reviews:20')
# ('thor_the_dark_world', 'page12', 'Total reviews:20')
# ('thor_the_dark_world', 'page13', 'Total reviews:20')
# ('thor_the_dark_world', 'page14', 'Total reviews:19')
# ('thor_the_dark_world', 'page15', 'Total reviews:20')
# ('thor_the_dark_world', 'page16', 'Total reviews:20')
# ('thor_the_dark_world', 'page17', 'Total reviews:20')
# ('thor_the_dark_world', 'page18', 'Total reviews:19')
# ('thor_the_dark_world', 'page19', 'Total reviews:20')
# ('thor_the_dark_world', 'page20', 'Total reviews:20')
# ('thor_the_dark_world', 'page21', 'Total reviews:20')
# ('thor_the_dark_world', 'page22', 'Total reviews:20')
# ('thor_the_dark_world', 'page23', 'Total reviews:20')
# ('thor_the_dark_world', 'page24', 'Total reviews:18')
# ('thor_the_dark_world', 'page25', 'Total reviews:20')
# ('thor_the_dark_world', 'page26', 'Total reviews:20')
# ('thor_the_dark_world', 'page27', 'Total reviews:20')
# ('thor_the_dark_world', 'page28', 'Total reviews:20')
# ('thor_the_dark_world', 'page29', 'Total reviews:20')
# ('thor_the_dark_world', 'page30', 'Total reviews:20')
# ('thor_the_dark_world', 'page31', 'Total reviews:20')
# ('thor_the_dark_world', 'page32', 'Total reviews:20')
# ('thor_the_dark_world', 'page33', 'Total reviews:20')
# ('thor_the_dark_world', 'page34', 'Total reviews:20')
# ('thor_the_dark_world', 'page35', 'Total reviews:18')
# ('thor_the_dark_world', 'page36', 'Total reviews:20')
# ('thor_the_dark_world', 'page37', 'Total reviews:20')
# ('thor_the_dark_world', 'page38', 'Total reviews:20')
# ('thor_the_dark_world', 'page39', 'Total reviews:19')
# ('thor_the_dark_world', 'page40', 'Total reviews:20')
# ('thor_the_dark_world', 'page41', 'Total reviews:19')
# ('thor_the_dark_world', 'page42', 'Total reviews:20')
# ('thor_the_dark_world', 'page43', 'Total reviews:20')
# ('thor_the_dark_world', 'page44', 'Total reviews:20')
# ('thor_the_dark_world', 'page45', 'Total reviews:20')
# ('thor_the_dark_world', 'page46', 'Total reviews:20')
# ('thor_the_dark_world', 'page47', 'Total reviews:20')
# ('thor_the_dark_world', 'page48', 'Total reviews:20')
# ('thor_the_dark_world', 'page49', 'Total reviews:20')
# ('thor_the_dark_world', 'page50', 'Total reviews:20')
# ('thor_the_dark_world', 'page51', 'Total reviews:20')
# ('thor_the_dark_world', 'Finished task 7', 'Total reviews:1010')
# ('captain_america_the_winter_soldier_2014', 'page1', 'Total reviews:20')
# ('captain_america_the_winter_soldier_2014', 'page2', 'Total reviews:20')
# ('captain_america_the_winter_soldier_2014', 'page3', 'Total reviews:20')
# ('captain_america_the_winter_soldier_2014', 'page4', 'Total reviews:20')
# ('captain_america_the_winter_soldier_2014', 'page5', 'Total reviews:20')
# ('captain_america_the_winter_soldier_2014', 'page6', 'Total reviews:19')
# ('captain_america_the_winter_soldier_2014', 'page7', 'Total reviews:20')
# ('captain_america_the_winter_soldier_2014', 'page8', 'Total reviews:20')
# ('captain_america_the_winter_soldier_2014', 'page9', 'Total reviews:20')
# ('captain_america_the_winter_soldier_2014', 'page10', 'Total reviews:19')
# ('captain_america_the_winter_soldier_2014', 'page11', 'Total reviews:19')
# ('captain_america_the_winter_soldier_2014', 'page12', 'Total reviews:20')
# ('captain_america_the_winter_soldier_2014', 'page13', 'Total reviews:20')
# ('captain_america_the_winter_soldier_2014', 'page14', 'Total reviews:20')
# ('captain_america_the_winter_soldier_2014', 'page15', 'Total reviews:20')
# ('captain_america_the_winter_soldier_2014', 'page16', 'Total reviews:20')
# ('captain_america_the_winter_soldier_2014', 'page17', 'Total reviews:20')
# ('captain_america_the_winter_soldier_2014', 'page18', 'Total reviews:20')
# ('captain_america_the_winter_soldier_2014', 'page19', 'Total reviews:19')
# ('captain_america_the_winter_soldier_2014', 'page20', 'Total reviews:19')
# ('captain_america_the_winter_soldier_2014', 'page21', 'Total reviews:20')
# ('captain_america_the_winter_soldier_2014', 'page22', 'Total reviews:19')
# ('captain_america_the_winter_soldier_2014', 'page23', 'Total reviews:20')
# ('captain_america_the_winter_soldier_2014', 'page24', 'Total reviews:20')
# ('captain_america_the_winter_soldier_2014', 'page25', 'Total reviews:19')
# ('captain_america_the_winter_soldier_2014', 'page26', 'Total reviews:20')
# ('captain_america_the_winter_soldier_2014', 'page27', 'Total reviews:20')
# ('captain_america_the_winter_soldier_2014', 'page28', 'Total reviews:20')
# ('captain_america_the_winter_soldier_2014', 'page29', 'Total reviews:20')
# ('captain_america_the_winter_soldier_2014', 'page30', 'Total reviews:20')
# ('captain_america_the_winter_soldier_2014', 'page31', 'Total reviews:19')
# ('captain_america_the_winter_soldier_2014', 'page32', 'Total reviews:20')
# ('captain_america_the_winter_soldier_2014', 'page33', 'Total reviews:19')
# ('captain_america_the_winter_soldier_2014', 'page34', 'Total reviews:19')
# ('captain_america_the_winter_soldier_2014', 'page35', 'Total reviews:19')
# ('captain_america_the_winter_soldier_2014', 'page36', 'Total reviews:20')
# ('captain_america_the_winter_soldier_2014', 'page37', 'Total reviews:20')
# ('captain_america_the_winter_soldier_2014', 'page38', 'Total reviews:20')
# ('captain_america_the_winter_soldier_2014', 'page39', 'Total reviews:19')
# ('captain_america_the_winter_soldier_2014', 'page40', 'Total reviews:19')
# ('captain_america_the_winter_soldier_2014', 'page41', 'Total reviews:20')
# ('captain_america_the_winter_soldier_2014', 'page42', 'Total reviews:20')
# ('captain_america_the_winter_soldier_2014', 'page43', 'Total reviews:20')
# ('captain_america_the_winter_soldier_2014', 'page44', 'Total reviews:20')
# ('captain_america_the_winter_soldier_2014', 'page45', 'Total reviews:20')
# ('captain_america_the_winter_soldier_2014', 'page46', 'Total reviews:20')
# ('captain_america_the_winter_soldier_2014', 'page47', 'Total reviews:20')
# ('captain_america_the_winter_soldier_2014', 'page48', 'Total reviews:18')
# ('captain_america_the_winter_soldier_2014', 'page49', 'Total reviews:20')
# ('captain_america_the_winter_soldier_2014', 'page50', 'Total reviews:20')
# ('captain_america_the_winter_soldier_2014', 'page51', 'Total reviews:20')
# ('captain_america_the_winter_soldier_2014', 'Finished task 8', 'Total reviews:1005')
# ('guardians_of_the_galaxy', 'page1', 'Total reviews:20')
# ('guardians_of_the_galaxy', 'page2', 'Total reviews:20')
# ('guardians_of_the_galaxy', 'page3', 'Total reviews:20')
# ('guardians_of_the_galaxy', 'page4', 'Total reviews:20')
# ('guardians_of_the_galaxy', 'page5', 'Total reviews:20')
# ('guardians_of_the_galaxy', 'page6', 'Total reviews:20')
# ('guardians_of_the_galaxy', 'page7', 'Total reviews:20')
# ('guardians_of_the_galaxy', 'page8', 'Total reviews:20')
# ('guardians_of_the_galaxy', 'page9', 'Total reviews:19')
# ('guardians_of_the_galaxy', 'page10', 'Total reviews:20')
# ('guardians_of_the_galaxy', 'page11', 'Total reviews:20')
# ('guardians_of_the_galaxy', 'page12', 'Total reviews:19')
# ('guardians_of_the_galaxy', 'page13', 'Total reviews:20')
# ('guardians_of_the_galaxy', 'page14', 'Total reviews:20')
# ('guardians_of_the_galaxy', 'page15', 'Total reviews:20')
# ('guardians_of_the_galaxy', 'page16', 'Total reviews:20')
# ('guardians_of_the_galaxy', 'page17', 'Total reviews:20')
# ('guardians_of_the_galaxy', 'page18', 'Total reviews:20')
# ('guardians_of_the_galaxy', 'page19', 'Total reviews:20')
# ('guardians_of_the_galaxy', 'page20', 'Total reviews:20')
# ('guardians_of_the_galaxy', 'page21', 'Total reviews:20')
# ('guardians_of_the_galaxy', 'page22', 'Total reviews:20')
# ('guardians_of_the_galaxy', 'page23', 'Total reviews:20')
# ('guardians_of_the_galaxy', 'page24', 'Total reviews:19')
# ('guardians_of_the_galaxy', 'page25', 'Total reviews:20')
# ('guardians_of_the_galaxy', 'page26', 'Total reviews:20')
# ('guardians_of_the_galaxy', 'page27', 'Total reviews:20')
# ('guardians_of_the_galaxy', 'page28', 'Total reviews:20')
# ('guardians_of_the_galaxy', 'page29', 'Total reviews:20')
# ('guardians_of_the_galaxy', 'page30', 'Total reviews:20')
# ('guardians_of_the_galaxy', 'page31', 'Total reviews:19')
# ('guardians_of_the_galaxy', 'page32', 'Total reviews:20')
# ('guardians_of_the_galaxy', 'page33', 'Total reviews:20')
# ('guardians_of_the_galaxy', 'page34', 'Total reviews:20')
# ('guardians_of_the_galaxy', 'page35', 'Total reviews:20')
# ('guardians_of_the_galaxy', 'page36', 'Total reviews:20')
# ('guardians_of_the_galaxy', 'page37', 'Total reviews:20')
# ('guardians_of_the_galaxy', 'page38', 'Total reviews:19')
# ('guardians_of_the_galaxy', 'page39', 'Total reviews:20')
# ('guardians_of_the_galaxy', 'page40', 'Total reviews:20')
# ('guardians_of_the_galaxy', 'page41', 'Total reviews:20')
# ('guardians_of_the_galaxy', 'page42', 'Total reviews:19')
# ('guardians_of_the_galaxy', 'page43', 'Total reviews:20')
# ('guardians_of_the_galaxy', 'page44', 'Total reviews:20')
# ('guardians_of_the_galaxy', 'page45', 'Total reviews:19')
# ('guardians_of_the_galaxy', 'page46', 'Total reviews:19')
# ('guardians_of_the_galaxy', 'page47', 'Total reviews:19')
# ('guardians_of_the_galaxy', 'page48', 'Total reviews:20')
# ('guardians_of_the_galaxy', 'page49', 'Total reviews:20')
# ('guardians_of_the_galaxy', 'page50', 'Total reviews:20')
# ('guardians_of_the_galaxy', 'page51', 'Total reviews:19')
# ('guardians_of_the_galaxy', 'Finished task 9', 'Total reviews:1010')
# ('guardians_of_the_galaxy_vol_2', 'page1', 'Total reviews:20')
# ('guardians_of_the_galaxy_vol_2', 'page2', 'Total reviews:20')
# ('guardians_of_the_galaxy_vol_2', 'page3', 'Total reviews:19')
# ('guardians_of_the_galaxy_vol_2', 'page4', 'Total reviews:20')
# ('guardians_of_the_galaxy_vol_2', 'page5', 'Total reviews:20')
# ('guardians_of_the_galaxy_vol_2', 'page6', 'Total reviews:20')
# ('guardians_of_the_galaxy_vol_2', 'page7', 'Total reviews:20')
# ('guardians_of_the_galaxy_vol_2', 'page8', 'Total reviews:20')
# ('guardians_of_the_galaxy_vol_2', 'page9', 'Total reviews:20')
# ('guardians_of_the_galaxy_vol_2', 'page10', 'Total reviews:18')
# ('guardians_of_the_galaxy_vol_2', 'page11', 'Total reviews:19')
# ('guardians_of_the_galaxy_vol_2', 'page12', 'Total reviews:20')
# ('guardians_of_the_galaxy_vol_2', 'page13', 'Total reviews:20')
# ('guardians_of_the_galaxy_vol_2', 'page14', 'Total reviews:20')
# ('guardians_of_the_galaxy_vol_2', 'page15', 'Total reviews:20')
# ('guardians_of_the_galaxy_vol_2', 'page16', 'Total reviews:20')
# ('guardians_of_the_galaxy_vol_2', 'page17', 'Total reviews:20')
# ('guardians_of_the_galaxy_vol_2', 'page18', 'Total reviews:20')
# ('guardians_of_the_galaxy_vol_2', 'page19', 'Total reviews:20')
# ('guardians_of_the_galaxy_vol_2', 'page20', 'Total reviews:20')
# ('guardians_of_the_galaxy_vol_2', 'page21', 'Total reviews:20')
# ('guardians_of_the_galaxy_vol_2', 'page22', 'Total reviews:20')
# ('guardians_of_the_galaxy_vol_2', 'page23', 'Total reviews:20')
# ('guardians_of_the_galaxy_vol_2', 'page24', 'Total reviews:19')
# ('guardians_of_the_galaxy_vol_2', 'page25', 'Total reviews:20')
# ('guardians_of_the_galaxy_vol_2', 'page26', 'Total reviews:20')
# ('guardians_of_the_galaxy_vol_2', 'page27', 'Total reviews:20')
# ('guardians_of_the_galaxy_vol_2', 'page28', 'Total reviews:20')
# ('guardians_of_the_galaxy_vol_2', 'page29', 'Total reviews:20')
# ('guardians_of_the_galaxy_vol_2', 'page30', 'Total reviews:19')
# ('guardians_of_the_galaxy_vol_2', 'page31', 'Total reviews:20')
# ('guardians_of_the_galaxy_vol_2', 'page32', 'Total reviews:20')
# ('guardians_of_the_galaxy_vol_2', 'page33', 'Total reviews:20')
# ('guardians_of_the_galaxy_vol_2', 'page34', 'Total reviews:19')
# ('guardians_of_the_galaxy_vol_2', 'page35', 'Total reviews:20')
# ('guardians_of_the_galaxy_vol_2', 'page36', 'Total reviews:20')
# ('guardians_of_the_galaxy_vol_2', 'page37', 'Total reviews:20')
# ('guardians_of_the_galaxy_vol_2', 'page38', 'Total reviews:20')
# ('guardians_of_the_galaxy_vol_2', 'page39', 'Total reviews:20')
# ('guardians_of_the_galaxy_vol_2', 'page40', 'Total reviews:20')
# ('guardians_of_the_galaxy_vol_2', 'page41', 'Total reviews:20')
# ('guardians_of_the_galaxy_vol_2', 'page42', 'Total reviews:20')
# ('avengers_age_of_ultron', 'page39', 'Total reviews:20')
# ('avengers_age_of_ultron', 'page40', 'Total reviews:20')
# ('avengers_age_of_ultron', 'page41', 'Total reviews:19')
# ('avengers_age_of_ultron', 'page42', 'Total reviews:20')
# ('avengers_age_of_ultron', 'page43', 'Total reviews:20')
# ('avengers_age_of_ultron', 'page44', 'Total reviews:20')
# ('avengers_age_of_ultron', 'page45', 'Total reviews:19')
# ('avengers_age_of_ultron', 'page46', 'Total reviews:20')
# ('avengers_age_of_ultron', 'page47', 'Total reviews:19')
# ('avengers_age_of_ultron', 'page48', 'Total reviews:19')
# ('avengers_age_of_ultron', 'page49', 'Total reviews:19')
# ('avengers_age_of_ultron', 'page50', 'Total reviews:20')
# ('avengers_age_of_ultron', 'page51', 'Total reviews:20')
# ('avengers_age_of_ultron', 'Finished task 11', 'Total reviews:1008')
# ('antman', 'page1', 'Total reviews:20')
# ('antman', 'page2', 'Total reviews:20')
# ('antman', 'page3', 'Total reviews:20')
# ('antman', 'page4', 'Total reviews:20')
# ('antman', 'page5', 'Total reviews:20')
# ('antman', 'page6', 'Total reviews:18')
# ('antman', 'page7', 'Total reviews:20')
# ('antman', 'page8', 'Total reviews:18')
# ('antman', 'page9', 'Total reviews:20')
# ('antman', 'page10', 'Total reviews:20')
# ('antman', 'page11', 'Total reviews:20')
# ('antman', 'page12', 'Total reviews:20')
# ('antman', 'page13', 'Total reviews:20')
# ('antman', 'page14', 'Total reviews:19')
# ('antman', 'page15', 'Total reviews:20')
# ('antman', 'page16', 'Total reviews:20')
# ('antman', 'page17', 'Total reviews:20')
# ('antman', 'page18', 'Total reviews:20')
# ('antman', 'page19', 'Total reviews:20')
# ('antman', 'page20', 'Total reviews:20')
# ('antman', 'page21', 'Total reviews:19')
# ('antman', 'page22', 'Total reviews:20')
# ('antman', 'page23', 'Total reviews:20')
# ('antman', 'page24', 'Total reviews:20')
# ('antman', 'page25', 'Total reviews:20')
# ('antman', 'page26', 'Total reviews:20')
# ('antman', 'page27', 'Total reviews:20')
# ('antman', 'page28', 'Total reviews:20')
# ('antman', 'page29', 'Total reviews:20')
# ('antman', 'page30', 'Total reviews:19')
# ('antman', 'page31', 'Total reviews:19')
# ('antman', 'page32', 'Total reviews:20')
# ('antman', 'page33', 'Total reviews:19')
# ('antman', 'page34', 'Total reviews:19')
# ('antman', 'page35', 'Total reviews:19')
# ('antman', 'page36', 'Total reviews:20')
# ('antman', 'page37', 'Total reviews:19')
# ('antman', 'page38', 'Total reviews:20')
# ('antman', 'page39', 'Total reviews:19')
# ('antman', 'page40', 'Total reviews:20')
# ('antman', 'page41', 'Total reviews:20')
# ('antman', 'page42', 'Total reviews:20')
# ('antman', 'page43', 'Total reviews:20')
# ('antman', 'page44', 'Total reviews:20')
# ('antman', 'page45', 'Total reviews:19')
# ('antman', 'page46', 'Total reviews:20')
# ('antman', 'page47', 'Total reviews:19')
# ('antman', 'page48', 'Total reviews:20')
# ('antman', 'page49', 'Total reviews:19')
# ('antman', 'page50', 'Total reviews:20')
# ('antman', 'page51', 'Total reviews:20')
# ('antman', 'Finished task 12', 'Total reviews:1004')
# ('captain_america_civil_war', 'page1', 'Total reviews:20')
# ('captain_america_civil_war', 'page2', 'Total reviews:20')
# ('captain_america_civil_war', 'page3', 'Total reviews:19')
# ('captain_america_civil_war', 'page4', 'Total reviews:20')
# ('captain_america_civil_war', 'page5', 'Total reviews:20')
# ('captain_america_civil_war', 'page6', 'Total reviews:20')
# ('captain_america_civil_war', 'page7', 'Total reviews:19')
# ('captain_america_civil_war', 'page8', 'Total reviews:20')
# ('captain_america_civil_war', 'page9', 'Total reviews:20')
# ('captain_america_civil_war', 'page10', 'Total reviews:19')
# ('captain_america_civil_war', 'page11', 'Total reviews:20')
# ('captain_america_civil_war', 'page12', 'Total reviews:19')
# ('captain_america_civil_war', 'page13', 'Total reviews:20')
# ('captain_america_civil_war', 'page14', 'Total reviews:20')
# ('captain_america_civil_war', 'page15', 'Total reviews:20')
# ('captain_america_civil_war', 'page16', 'Total reviews:20')
# ('captain_america_civil_war', 'page17', 'Total reviews:20')
# ('captain_america_civil_war', 'page18', 'Total reviews:20')
# ('captain_america_civil_war', 'page19', 'Total reviews:19')
# ('captain_america_civil_war', 'page20', 'Total reviews:20')
# ('captain_america_civil_war', 'page21', 'Total reviews:20')
# ('captain_america_civil_war', 'page22', 'Total reviews:20')
# ('captain_america_civil_war', 'page23', 'Total reviews:20')
# ('captain_america_civil_war', 'page24', 'Total reviews:20')
# ('captain_america_civil_war', 'page25', 'Total reviews:20')
# ('captain_america_civil_war', 'page26', 'Total reviews:20')
# ('captain_america_civil_war', 'page27', 'Total reviews:20')
# ('captain_america_civil_war', 'page28', 'Total reviews:20')
# ('captain_america_civil_war', 'page29', 'Total reviews:20')
# ('captain_america_civil_war', 'page30', 'Total reviews:20')
# ('captain_america_civil_war', 'page31', 'Total reviews:20')
# ('captain_america_civil_war', 'page32', 'Total reviews:20')
# ('captain_america_civil_war', 'page33', 'Total reviews:19')
# ('captain_america_civil_war', 'page34', 'Total reviews:20')
# ('captain_america_civil_war', 'page35', 'Total reviews:20')
# ('captain_america_civil_war', 'page36', 'Total reviews:19')
# ('captain_america_civil_war', 'page37', 'Total reviews:20')
# ('captain_america_civil_war', 'page38', 'Total reviews:19')
# ('captain_america_civil_war', 'page39', 'Total reviews:20')
# ('captain_america_civil_war', 'page40', 'Total reviews:20')
# ('captain_america_civil_war', 'page41', 'Total reviews:19')
# ('captain_america_civil_war', 'page42', 'Total reviews:19')
# ('captain_america_civil_war', 'page43', 'Total reviews:20')
# ('captain_america_civil_war', 'page44', 'Total reviews:20')
# ('captain_america_civil_war', 'page45', 'Total reviews:19')
# ('captain_america_civil_war', 'page46', 'Total reviews:20')
# ('captain_america_civil_war', 'page47', 'Total reviews:19')
# ('captain_america_civil_war', 'page48', 'Total reviews:20')
# ('captain_america_civil_war', 'page49', 'Total reviews:20')
# ('captain_america_civil_war', 'page50', 'Total reviews:20')
# ('captain_america_civil_war', 'page51', 'Total reviews:20')
# ('captain_america_civil_war', 'Finished task 13', 'Total reviews:1008')
# ('spider_man_homecoming', 'page1', 'Total reviews:20')
# ('spider_man_homecoming', 'page2', 'Total reviews:20')
# ('spider_man_homecoming', 'page3', 'Total reviews:20')
# ('spider_man_homecoming', 'page4', 'Total reviews:20')
# ('spider_man_homecoming', 'page5', 'Total reviews:20')
# ('spider_man_homecoming', 'page6', 'Total reviews:19')
# ('spider_man_homecoming', 'page7', 'Total reviews:20')
# ('spider_man_homecoming', 'page8', 'Total reviews:20')
# ('spider_man_homecoming', 'page9', 'Total reviews:20')
# ('spider_man_homecoming', 'page10', 'Total reviews:20')
# ('spider_man_homecoming', 'page11', 'Total reviews:20')
# ('spider_man_homecoming', 'page12', 'Total reviews:20')
# ('spider_man_homecoming', 'page13', 'Total reviews:20')
# ('spider_man_homecoming', 'page14', 'Total reviews:19')
# ('spider_man_homecoming', 'page15', 'Total reviews:20')
# ('spider_man_homecoming', 'page16', 'Total reviews:20')
# ('spider_man_homecoming', 'page17', 'Total reviews:20')
# ('spider_man_homecoming', 'page18', 'Total reviews:20')
# ('spider_man_homecoming', 'page19', 'Total reviews:20')
# ('spider_man_homecoming', 'page20', 'Total reviews:20')
# ('spider_man_homecoming', 'page21', 'Total reviews:20')
# ('spider_man_homecoming', 'page22', 'Total reviews:20')
# ('spider_man_homecoming', 'page23', 'Total reviews:20')
# ('spider_man_homecoming', 'page24', 'Total reviews:20')
# ('spider_man_homecoming', 'page25', 'Total reviews:20')
# ('spider_man_homecoming', 'page26', 'Total reviews:20')
# ('spider_man_homecoming', 'page27', 'Total reviews:20')
# ('spider_man_homecoming', 'page28', 'Total reviews:20')
# ('spider_man_homecoming', 'page29', 'Total reviews:20')
# ('spider_man_homecoming', 'page30', 'Total reviews:20')
# ('spider_man_homecoming', 'page31', 'Total reviews:20')
# ('spider_man_homecoming', 'page32', 'Total reviews:20')
# ('spider_man_homecoming', 'page33', 'Total reviews:20')
# ('spider_man_homecoming', 'page34', 'Total reviews:20')
# ('spider_man_homecoming', 'page35', 'Total reviews:20')
# ('spider_man_homecoming', 'page36', 'Total reviews:19')
# ('spider_man_homecoming', 'page37', 'Total reviews:20')
# ('spider_man_homecoming', 'page38', 'Total reviews:20')
# ('spider_man_homecoming', 'page39', 'Total reviews:20')
# ('spider_man_homecoming', 'page40', 'Total reviews:20')
# ('spider_man_homecoming', 'page41', 'Total reviews:20')
# ('spider_man_homecoming', 'page42', 'Total reviews:20')
# ('spider_man_homecoming', 'page43', 'Total reviews:20')
# ('spider_man_homecoming', 'page44', 'Total reviews:20')
# ('spider_man_homecoming', 'page45', 'Total reviews:20')
# ('spider_man_homecoming', 'page46', 'Total reviews:20')
# ('spider_man_homecoming', 'page47', 'Total reviews:20')
# ('spider_man_homecoming', 'page48', 'Total reviews:20')
# ('spider_man_homecoming', 'page49', 'Total reviews:20')
# ('spider_man_homecoming', 'page50', 'Total reviews:20')
# ('spider_man_homecoming', 'page51', 'Total reviews:20')
# ('spider_man_homecoming', 'Finished task 14', 'Total reviews:1017')
# ('doctor_strange_2016', 'page1', 'Total reviews:19')
# ('doctor_strange_2016', 'page2', 'Total reviews:20')
# ('doctor_strange_2016', 'page3', 'Total reviews:19')
# ('doctor_strange_2016', 'page4', 'Total reviews:20')
# ('doctor_strange_2016', 'page5', 'Total reviews:20')
# ('doctor_strange_2016', 'page6', 'Total reviews:20')
# ('doctor_strange_2016', 'page7', 'Total reviews:20')
# ('doctor_strange_2016', 'page8', 'Total reviews:20')
# ('doctor_strange_2016', 'page9', 'Total reviews:19')
# ('doctor_strange_2016', 'page10', 'Total reviews:20')
# ('doctor_strange_2016', 'page11', 'Total reviews:20')
# ('doctor_strange_2016', 'page12', 'Total reviews:20')
# ('doctor_strange_2016', 'page13', 'Total reviews:20')
# ('doctor_strange_2016', 'page14', 'Total reviews:20')
# ('doctor_strange_2016', 'page15', 'Total reviews:20')
# ('doctor_strange_2016', 'page16', 'Total reviews:20')
# ('doctor_strange_2016', 'page17', 'Total reviews:20')
# ('doctor_strange_2016', 'page18', 'Total reviews:20')
# ('doctor_strange_2016', 'page19', 'Total reviews:20')
# ('doctor_strange_2016', 'page20', 'Total reviews:20')
# ('doctor_strange_2016', 'page21', 'Total reviews:20')
# ('doctor_strange_2016', 'page22', 'Total reviews:20')
# ('doctor_strange_2016', 'page23', 'Total reviews:20')
# ('doctor_strange_2016', 'page24', 'Total reviews:20')
# ('doctor_strange_2016', 'page25', 'Total reviews:20')
# ('doctor_strange_2016', 'page26', 'Total reviews:20')
# ('doctor_strange_2016', 'page27', 'Total reviews:20')
# ('doctor_strange_2016', 'page28', 'Total reviews:20')
# ('doctor_strange_2016', 'page29', 'Total reviews:20')
# ('doctor_strange_2016', 'page30', 'Total reviews:20')
# ('doctor_strange_2016', 'page31', 'Total reviews:20')
# ('doctor_strange_2016', 'page32', 'Total reviews:20')
# ('doctor_strange_2016', 'page33', 'Total reviews:20')
# ('doctor_strange_2016', 'page34', 'Total reviews:20')
# ('doctor_strange_2016', 'page35', 'Total reviews:20')
# ('doctor_strange_2016', 'page36', 'Total reviews:20')
# ('doctor_strange_2016', 'page37', 'Total reviews:19')
# ('doctor_strange_2016', 'page38', 'Total reviews:20')
# ('doctor_strange_2016', 'page39', 'Total reviews:20')
# ('doctor_strange_2016', 'page40', 'Total reviews:20')
# ('doctor_strange_2016', 'page41', 'Total reviews:20')
# ('doctor_strange_2016', 'page42', 'Total reviews:20')
# ('doctor_strange_2016', 'page43', 'Total reviews:20')
# ('doctor_strange_2016', 'page44', 'Total reviews:20')
# ('doctor_strange_2016', 'page45', 'Total reviews:20')
# ('doctor_strange_2016', 'page46', 'Total reviews:20')
# ('doctor_strange_2016', 'page47', 'Total reviews:20')
# ('doctor_strange_2016', 'page48', 'Total reviews:20')
# ('doctor_strange_2016', 'page49', 'Total reviews:20')
# ('doctor_strange_2016', 'page50', 'Total reviews:19')
# ('doctor_strange_2016', 'page51', 'Total reviews:20')
# ('doctor_strange_2016', 'Finished task 15', 'Total reviews:1015')
# ('thor_ragnarok_2017', 'page1', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page2', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page3', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page4', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page5', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page6', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page7', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page8', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page9', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page10', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page11', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page12', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page13', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page14', 'Total reviews:19')
# ('thor_ragnarok_2017', 'page15', 'Total reviews:19')
# ('thor_ragnarok_2017', 'page16', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page17', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page18', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page19', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page20', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page21', 'Total reviews:19')
# ('thor_ragnarok_2017', 'page22', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page23', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page24', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page25', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page26', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page27', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page28', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page29', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page30', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page31', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page32', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page33', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page34', 'Total reviews:19')
# ('thor_ragnarok_2017', 'page35', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page36', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page37', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page38', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page39', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page40', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page41', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page42', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page43', 'Total reviews:19')
# ('thor_ragnarok_2017', 'page44', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page45', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page46', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page47', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page48', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page49', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page50', 'Total reviews:20')
# ('thor_ragnarok_2017', 'page51', 'Total reviews:20')
# ('thor_ragnarok_2017', 'Finished task 16', 'Total reviews:1015')
# ('black_panther_2018', 'page1', 'Total reviews:20')
# ('black_panther_2018', 'page2', 'Total reviews:20')
# ('black_panther_2018', 'page3', 'Total reviews:20')
# ('black_panther_2018', 'page4', 'Total reviews:20')
# ('black_panther_2018', 'page5', 'Total reviews:20')
# ('black_panther_2018', 'page6', 'Total reviews:20')
# ('black_panther_2018', 'page7', 'Total reviews:20')
# ('black_panther_2018', 'page8', 'Total reviews:20')
# ('black_panther_2018', 'page9', 'Total reviews:20')
# ('black_panther_2018', 'page10', 'Total reviews:20')
# ('black_panther_2018', 'page11', 'Total reviews:20')
# ('black_panther_2018', 'page12', 'Total reviews:20')
# ('black_panther_2018', 'page13', 'Total reviews:20')
# ('black_panther_2018', 'page14', 'Total reviews:20')
# ('black_panther_2018', 'page15', 'Total reviews:20')
# ('black_panther_2018', 'page16', 'Total reviews:20')
# ('black_panther_2018', 'page17', 'Total reviews:20')
# ('black_panther_2018', 'page18', 'Total reviews:19')
# ('black_panther_2018', 'page19', 'Total reviews:19')
# ('black_panther_2018', 'page20', 'Total reviews:20')
# ('black_panther_2018', 'page21', 'Total reviews:20')
# ('black_panther_2018', 'page22', 'Total reviews:20')
# ('black_panther_2018', 'page23', 'Total reviews:20')
# ('black_panther_2018', 'page24', 'Total reviews:20')
# ('black_panther_2018', 'page25', 'Total reviews:20')
# ('black_panther_2018', 'page26', 'Total reviews:19')
# ('black_panther_2018', 'page27', 'Total reviews:20')
# ('black_panther_2018', 'page28', 'Total reviews:19')
# ('black_panther_2018', 'page29', 'Total reviews:20')
# ('black_panther_2018', 'page30', 'Total reviews:20')
# ('black_panther_2018', 'page31', 'Total reviews:19')
# ('black_panther_2018', 'page32', 'Total reviews:20')
# ('black_panther_2018', 'page33', 'Total reviews:20')
# ('black_panther_2018', 'page34', 'Total reviews:20')
# ('black_panther_2018', 'page35', 'Total reviews:20')
# ('black_panther_2018', 'page36', 'Total reviews:19')
# ('black_panther_2018', 'page37', 'Total reviews:20')
# ('black_panther_2018', 'page38', 'Total reviews:20')
# ('black_panther_2018', 'page39', 'Total reviews:20')
# ('black_panther_2018', 'page40', 'Total reviews:20')
# ('black_panther_2018', 'page41', 'Total reviews:20')
# ('black_panther_2018', 'page42', 'Total reviews:20')
# ('black_panther_2018', 'page43', 'Total reviews:20')
# ('black_panther_2018', 'page44', 'Total reviews:20')
# ('black_panther_2018', 'page45', 'Total reviews:20')
# ('black_panther_2018', 'page46', 'Total reviews:20')
# ('black_panther_2018', 'page47', 'Total reviews:19')
# ('black_panther_2018', 'page48', 'Total reviews:20')
# ('black_panther_2018', 'page49', 'Total reviews:20')
# ('black_panther_2018', 'page50', 'Total reviews:20')
# ('black_panther_2018', 'page51', 'Total reviews:20')
# ('black_panther_2018', 'Finished task 17', 'Total reviews:1013')
# ('avengers_infinity_war', 'page1', 'Total reviews:20')
# ('avengers_infinity_war', 'page2', 'Total reviews:19')
# ('avengers_infinity_war', 'page3', 'Total reviews:20')
# ('avengers_infinity_war', 'page4', 'Total reviews:20')
# ('avengers_infinity_war', 'page5', 'Total reviews:20')
# ('avengers_infinity_war', 'page6', 'Total reviews:20')
# ('avengers_infinity_war', 'page7', 'Total reviews:20')
# ('avengers_infinity_war', 'page8', 'Total reviews:20')
# ('avengers_infinity_war', 'page9', 'Total reviews:20')
# ('avengers_infinity_war', 'page10', 'Total reviews:20')
# ('avengers_infinity_war', 'page11', 'Total reviews:20')
# ('avengers_infinity_war', 'page12', 'Total reviews:20')
# ('avengers_infinity_war', 'page13', 'Total reviews:20')
# ('avengers_infinity_war', 'page14', 'Total reviews:20')
# ('avengers_infinity_war', 'page15', 'Total reviews:20')
# ('avengers_infinity_war', 'page16', 'Total reviews:19')
# ('avengers_infinity_war', 'page17', 'Total reviews:20')
# ('avengers_infinity_war', 'page18', 'Total reviews:20')
# ('avengers_infinity_war', 'page19', 'Total reviews:20')
# ('avengers_infinity_war', 'page20', 'Total reviews:20')
# ('avengers_infinity_war', 'page21', 'Total reviews:20')
# ('avengers_infinity_war', 'page22', 'Total reviews:20')
# ('avengers_infinity_war', 'page23', 'Total reviews:20')
# ('avengers_infinity_war', 'page24', 'Total reviews:19')
# ('avengers_infinity_war', 'page25', 'Total reviews:19')
# ('avengers_infinity_war', 'page26', 'Total reviews:20')
# ('avengers_infinity_war', 'page27', 'Total reviews:19')
# ('avengers_infinity_war', 'page28', 'Total reviews:19')
# ('avengers_infinity_war', 'page29', 'Total reviews:20')
# ('avengers_infinity_war', 'page30', 'Total reviews:20')
# ('avengers_infinity_war', 'page31', 'Total reviews:19')
# ('avengers_infinity_war', 'page32', 'Total reviews:20')
# ('avengers_infinity_war', 'page33', 'Total reviews:20')
# ('avengers_infinity_war', 'page34', 'Total reviews:20')
# ('avengers_infinity_war', 'page35', 'Total reviews:19')
# ('avengers_infinity_war', 'page36', 'Total reviews:20')
# ('avengers_infinity_war', 'page37', 'Total reviews:20')
# ('avengers_infinity_war', 'page38', 'Total reviews:20')
# ('avengers_infinity_war', 'page39', 'Total reviews:20')
# ('avengers_infinity_war', 'page40', 'Total reviews:20')
# ('avengers_infinity_war', 'page41', 'Total reviews:18')
# ('avengers_infinity_war', 'page42', 'Total reviews:20')
# ('avengers_infinity_war', 'page43', 'Total reviews:20')
# ('avengers_infinity_war', 'page44', 'Total reviews:20')
# ('avengers_infinity_war', 'page45', 'Total reviews:20')
# ('avengers_infinity_war', 'page46', 'Total reviews:20')
# ('avengers_infinity_war', 'page47', 'Total reviews:20')
# ('avengers_infinity_war', 'page48', 'Total reviews:20')
# ('avengers_infinity_war', 'page49', 'Total reviews:20')
# ('avengers_infinity_war', 'page50', 'Total reviews:20')
# ('avengers_infinity_war', 'page51', 'Total reviews:19')
# ('avengers_infinity_war', 'Finished task 18', 'Total reviews:1009')
# ('ant_man_and_the_wasp', 'page1', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'page2', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'page3', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'page4', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'page5', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'page6', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'page7', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'page8', 'Total reviews:19')
# ('ant_man_and_the_wasp', 'page9', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'page10', 'Total reviews:19')
# ('ant_man_and_the_wasp', 'page11', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'page12', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'page13', 'Total reviews:19')
# ('ant_man_and_the_wasp', 'page14', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'page15', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'page16', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'page17', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'page18', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'page19', 'Total reviews:19')
# ('ant_man_and_the_wasp', 'page20', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'page21', 'Total reviews:19')
# ('ant_man_and_the_wasp', 'page22', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'page23', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'page24', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'page25', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'page26', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'page27', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'page28', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'page29', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'page30', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'page31', 'Total reviews:19')
# ('ant_man_and_the_wasp', 'page32', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'page33', 'Total reviews:19')
# ('ant_man_and_the_wasp', 'page34', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'page35', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'page36', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'page37', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'page38', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'page39', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'page40', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'page41', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'page42', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'page43', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'page44', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'page45', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'page46', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'page47', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'page48', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'page49', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'page50', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'page51', 'Total reviews:20')
# ('ant_man_and_the_wasp', 'Finished task 19', 'Total reviews:1013')
# ('captain_marvel', 'page1', 'Total reviews:20')
# ('captain_marvel', 'page2', 'Total reviews:20')
# ('captain_marvel', 'page3', 'Total reviews:20')
# ('captain_marvel', 'page4', 'Total reviews:20')
# ('captain_marvel', 'page5', 'Total reviews:20')
# ('captain_marvel', 'page6', 'Total reviews:19')
# ('captain_marvel', 'page7', 'Total reviews:19')
# ('captain_marvel', 'page8', 'Total reviews:20')
# ('captain_marvel', 'page9', 'Total reviews:20')
# ('captain_marvel', 'page10', 'Total reviews:19')
# ('captain_marvel', 'page11', 'Total reviews:20')
# ('captain_marvel', 'page12', 'Total reviews:20')
# ('captain_marvel', 'page13', 'Total reviews:20')
# ('captain_marvel', 'page14', 'Total reviews:19')
# ('captain_marvel', 'page15', 'Total reviews:20')
# ('captain_marvel', 'page16', 'Total reviews:20')
# ('captain_marvel', 'page17', 'Total reviews:20')
# ('captain_marvel', 'page18', 'Total reviews:20')
# ('captain_marvel', 'page19', 'Total reviews:20')
# ('captain_marvel', 'page20', 'Total reviews:20')
# ('captain_marvel', 'page21', 'Total reviews:20')
# ('captain_marvel', 'page22', 'Total reviews:20')
# ('captain_marvel', 'page23', 'Total reviews:20')
# ('captain_marvel', 'page24', 'Total reviews:20')
# ('captain_marvel', 'page25', 'Total reviews:20')
# ('captain_marvel', 'page26', 'Total reviews:20')
# ('captain_marvel', 'page27', 'Total reviews:20')
# ('captain_marvel', 'page28', 'Total reviews:20')
# ('captain_marvel', 'page29', 'Total reviews:19')
# ('captain_marvel', 'page30', 'Total reviews:20')
# ('captain_marvel', 'page31', 'Total reviews:20')
# ('captain_marvel', 'page32', 'Total reviews:20')
# ('captain_marvel', 'page33', 'Total reviews:20')
# ('captain_marvel', 'page34', 'Total reviews:20')
# ('captain_marvel', 'page35', 'Total reviews:20')
# ('captain_marvel', 'page36', 'Total reviews:20')
# ('captain_marvel', 'page37', 'Total reviews:20')
# ('captain_marvel', 'page38', 'Total reviews:20')
# ('captain_marvel', 'page39', 'Total reviews:20')
# ('captain_marvel', 'page40', 'Total reviews:20')
# ('captain_marvel', 'page41', 'Total reviews:20')
# ('captain_marvel', 'page42', 'Total reviews:19')
# ('captain_marvel', 'page43', 'Total reviews:20')
# ('captain_marvel', 'page44', 'Total reviews:20')
# ('captain_marvel', 'page45', 'Total reviews:20')
# ('captain_marvel', 'page46', 'Total reviews:20')
# ('captain_marvel', 'page47', 'Total reviews:20')
# ('captain_marvel', 'page48', 'Total reviews:20')
# ('captain_marvel', 'page49', 'Total reviews:20')
# ('captain_marvel', 'page50', 'Total reviews:20')
# ('captain_marvel', 'page51', 'Total reviews:20')
# ('captain_marvel', 'Finished task 20', 'Total reviews:1014')

# %% [markdown]
# # Merge csv files
# https://www.cnblogs.com/taolusi/p/9292995.html

# %%
for i in Movies['name']:
    df = pd.read_csv('Reviews_Marvel/'+i+'.csv')
    df['name'] = i
    df.to_csv('Reviews_Marvel.csv', mode='a+', index=False, header=False)
    print(df.shape[0], i)
# Out:
# (1006, 'Captain America: The First Avenger')
# (1007, 'Iron Man')
# (1010, 'The Incredible Hulk')
# (1007, 'Iron Man 2')
# (1009, 'Thor')
# (1008, 'The Avengers')
# (1005, 'Iron Man Three')
# (1010, 'Thor: The Dark World')
# (1005, 'Captain America: The Winter Soldier')
# (1010, 'Guardians of the Galaxy')
# (1012, 'Guardians of the Galaxy Vol. 2')
# (1008, 'Avengers: Age of Ultron')
# (1004, 'Ant-Man')
# (1008, 'Captain America: Civil War')
# (1017, 'Spider-Man: Homecoming')
# (1015, 'Doctor Strange')
# (1015, 'Thor: Ragnarok')
# (1013, 'Black Panther')
# (1009, 'Avengers: Infinity War')
# (1013, 'Ant-Man and the Wasp')
# (1014, 'Captain Marvel')

# %%
df = pd.read_csv('Reviews_Marvel/'+i+'.csv')
df.head()
# Out:
#                                               review  stars            date
# 0    I don't care about what people say, I think ...    5.0  April 13, 2019
# 1    Captain Marvel wasn't as great as many of Ma...    3.0  April 13, 2019
# 2    Really decent movie, rounds it together well...    4.0  April 13, 2019
# 3    A solid, entertaining marvel film with amazi...    4.0  April 13, 2019
# 4    Slow at first but was really good, kind of f...    3.0  April 13, 2019

# %%
# add header & column order
df = pd.read_csv('Reviews_Marvel.csv', header=None).drop_duplicates()
df.columns = ['review', 'stars', 'date', 'name']
columns = ['name', 'review', 'stars', 'date']
df.to_csv('Reviews_Marvel.csv', index=False, columns=columns)
print(df.shape)
df.head()
# Out:
# (21186, 4)
#                                               review  stars            date  \
# 0    Captain America: The First Avenger might not...    3.5  April 11, 2019
# 1    It starts well, but later, it goes like a ca...    3.0  April 11, 2019
# 2    Chris Evans, with a physique so chiseled, ca...    2.0   April 9, 2019
# 3    (78/100)Captain America: The First Avenger i...    4.0   April 8, 2019
# 4    The overly patriotic aspect of the character...    1.0   April 7, 2019
#
#                                  name
# 0  Captain America: The First Avenger
# 1  Captain America: The First Avenger
# 2  Captain America: The First Avenger
# 3  Captain America: The First Avenger
# 4  Captain America: The First Avenger

# %%
df = pd.read_csv('Reviews_Marvel.csv')
print(df.shape)
df.head()
# Out:
# (21186, 4)
#                                  name  \
# 0  Captain America: The First Avenger
# 1  Captain America: The First Avenger
# 2  Captain America: The First Avenger
# 3  Captain America: The First Avenger
# 4  Captain America: The First Avenger
#
#                                               review  stars            date
# 0    Captain America: The First Avenger might not...    3.5  April 11, 2019
# 1    It starts well, but later, it goes like a ca...    3.0  April 11, 2019
# 2    Chris Evans, with a physique so chiseled, ca...    2.0   April 9, 2019
# 3    (78/100)Captain America: The First Avenger i...    4.0   April 8, 2019
# 4    The overly patriotic aspect of the character...    1.0   April 7, 2019

# %%
len(df['name'].unique())
# Out:
# 21
